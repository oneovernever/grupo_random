# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# 1. Dado el registro de notas de los alumnos de la forma (padrón, materia, nota, fecha). Se pide resolver utilizando Pandas:

# %%
df = pd.DataFrame(columns=['padron','materia','nota','fecha'])

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [padron, materia, nota, fecha]
# Index: []

# %%
# Generemos notas aleatoreas.
df.nota = np.sort(np.random.randint(60,100, 25))

# %%
#Generemos fechas aleatoreas.
start_date = pd.to_datetime('2018-06-30')
end_date = pd.to_datetime('2020-11-30')

def gen_rand_date(group, start_date = start_date, end_date = end_date):
    # step 1 in description above:
    days = (end_date - start_date).days
    # step 2:
    d = pd.np.sort(pd.np.random.choice(range(days), len(group)))
    # step 3:
    return start_date + pd.to_timedelta(d,unit='D')

df['fecha'] = df.transform(lambda x: gen_rand_date(x))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead

# %%
#Generemos materias aleatoreas.
materias = df.materia.apply(lambda x: np.random.choice(['org de datos', 'algoritmos','estadistica','cocina Africana intensiva']) )
df.materia = materias

# %%
#Generemos padrones aleatoreos.
padrones = df.padron.apply(lambda x: np.random.choice(['1010', '1020','1030']) )
df.padron = padrones

# %%
# A. estadisticas de las notas incluyendo el promedio
df.describe()
# Out:
#            nota
# count  25.00000
# mean   75.84000
# std     9.76678
# min    60.00000
# 25%    69.00000
# 50%    76.00000
# 75%    81.00000
# max    99.00000

# %%
 # A.1 grafico de distribucion de las notas
plt.hist(df.nota,bins=10)
# Out:
# (array([4., 0., 6., 2., 4., 3., 2., 3., 0., 1.]),
#  array([60. , 63.9, 67.8, 71.7, 75.6, 79.5, 83.4, 87.3, 91.2, 95.1, 99. ]),
#  <a list of 10 Patch objects>)

# %%
# B. Cual es la nota mas alta y baja del 2019?
df[df['fecha'].dt.year == 2019].describe()
# Out:
#             nota
# count  12.000000
# mean   76.166667
# std     3.857303
# min    71.000000
# 25%    73.250000
# 50%    76.500000
# 75%    78.750000
# max    81.000000

# %%
# C. Cuál es el padrón con mayor cantidad de materias aprobadas (>75) durante el último cuatrimestre
df[df.nota > 75].groupby('padron')['nota'].count().sort_values(ascending=False)
# Out:
# padron
# 1020    6
# 1010    4
# 1030    3
# Name: nota, dtype: int64

# %%
# D. Cuál es la nota promedio
df.nota.mean()
# Out:
# 75.84

# %%
# E. Cuál es la nota promedio por padrón.
df.groupby('padron')['nota'].mean()
# Out:
# padron
# 1010    77.375000
# 1020    75.090909
# 1030    75.166667
# Name: nota, dtype: float64

# %% [markdown]
# 2. Se tiene un registro de transacciones bancarias, de la forma (nro de transacción, tipo de transacción, cuenta origen, cuenta destino, fecha, hora, monto). Se pide resolver en Pandas:

# %%
#Validar que todas las transacciones cuenten con un tipo de transacción.

# %%
#Validar que para las transacciones del tipo transferencia, exista siempre tanto cuenta origen como cuenta destino.

# %%
#Verificar que todas las transacciones del tipo transferencia, depósito y extracción cuenten con montos distintos de cero.

# %%
#Indicar cuáles fueron las 10 transacciones de mayor monto.

# %%
#Indicar cuál es el tipo de transacción que registra mayor monto promedio.

# %%
#Indicar cuáles son las 5 cuentas con mayor cantidad de transacciones.

# %%
#Indicar cuáles son las 5 cuentas con mayor monto involucrado.

# %%
#Para el tipo de transacción con mayor cantidad de monto promedio, indicar cuales son las 5 cuentas con más transacciones.
